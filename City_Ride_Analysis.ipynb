# %%
#Add Matplotlib inline magic command
# %matplotlib inline

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
#Load in ride csv data source
ride_df = pd.read_csv("Resources/ride_data.csv")
ride_df.head(10)
# Out:
#                  city                 date   fare        ride_id
# 0  Lake Jonathanshire  2019-01-14 10:14:22  13.83  5739410935873
# 1  South Michelleport  2019-03-04 18:24:09  30.24  2343912425577
# 2  Port Samanthamouth  2019-02-24 04:29:00  33.44  2005065760003
# 3          Rodneyfort  2019-02-10 23:22:03  23.44  5149245426178
# 4          South Jack  2019-03-06 04:28:35  34.58  3908451377344
# 5        South Latoya  2019-03-11 12:26:48   9.52  1994999424437
# 6       New Paulville  2019-02-27 11:17:56  43.25   793208410091
# 7        Simpsonburgh  2019-04-26 00:43:24  35.98   111953927754
# 8     South Karenland  2019-01-08 03:28:48  35.09  7995623208694
# 9       North Jasmine  2019-03-09 06:26:29  42.81  5327642267789

# %%
#Inspecting Ride Data

# %%
ride_df.count()
# Out:
# city       2375
# date       2375
# fare       2375
# ride_id    2375
# dtype: int64

# %%
#Get columns and rows that are NOT null
ride_df.isnull().sum()
# Out:
# city       0
# date       0
# fare       0
# ride_id    0
# dtype: int64

# %%
#Data Type for each column
ride_df.dtypes
# Out:
# city        object
# date        object
# fare       float64
# ride_id      int64
# dtype: object

# %%
#Load in city csv data source
city_df = pd.read_csv("Resources/city_data.csv")
city_df.head(10)
# Out:
#             city  driver_count   type
# 0    Richardfort            38  Urban
# 1   Williamsstad            59  Urban
# 2    Port Angela            67  Urban
# 3     Rodneyfort            34  Urban
# 4    West Robert            39  Urban
# 5   West Anthony            70  Urban
# 6    West Angela            48  Urban
# 7  Martinezhaven            25  Urban
# 8      Karenberg            22  Urban
# 9    Barajasview            26  Urban

# %%
#Inspecting City data
#Number of rows in city_df
city_df.count()
# Out:
# city            120
# driver_count    120
# type            120
# dtype: int64

# %%
#Get the columns and rows that are NOT null in city_df
city_df.isnull().sum()
# Out:
# city            0
# driver_count    0
# type            0
# dtype: int64

# %%
#Determine the data types for each column
city_df.dtypes
# Out:
# city            object
# driver_count     int64
# type            object
# dtype: object

# %%
#Each Type of City
city_df["type"].unique()
# Out:
# array(['Urban', 'Suburban', 'Rural'], dtype=object)

# %%
# Number of data points for Urban cities
sum(city_df['type']=="Urban")
# Out:
# 66

# %%
# Number of data points for Suburban cities
sum(city_df['type']=="Suburban")
# Out:
# 36

# %%
#Number of data points for Rural cities
sum(city_df['type']=="Rural")
# Out:
# 18

# %%
#Merging DataFrames
ride_city_df = pd.merge(ride_df,city_df,how="left",on=["city","city"])
ride_city_df
# Out:
#                     city                 date   fare        ride_id  \
# 0     Lake Jonathanshire  2019-01-14 10:14:22  13.83  5739410935873
# 1     South Michelleport  2019-03-04 18:24:09  30.24  2343912425577
# 2     Port Samanthamouth  2019-02-24 04:29:00  33.44  2005065760003
# 3             Rodneyfort  2019-02-10 23:22:03  23.44  5149245426178
# 4             South Jack  2019-03-06 04:28:35  34.58  3908451377344
# ...                  ...                  ...    ...            ...
# 2370         Michaelberg  2019-04-29 17:04:39  13.38  8550365057598
# 2371     Lake Latoyabury  2019-01-30 00:05:47  20.76  9018727594352
# 2372         North Jaime  2019-02-10 21:03:50  11.11  2781339863778
# 2373        West Heather  2019-05-07 19:22:15  44.94  4256853490277
# 2374          Newtonview  2019-04-25 10:20:13  55.84  9990581345298
#
#       driver_count   type
# 0                5  Urban
# 1               72  Urban
# 2               57  Urban
# 3               34  Urban
# ...

# %%
#Create Urban City Data Frame
urban_cities_df = ride_city_df[ride_city_df["type"]=="Urban"]
urban_cities_df.head()
# Out:
#                  city                 date   fare        ride_id  \
# 0  Lake Jonathanshire  2019-01-14 10:14:22  13.83  5739410935873
# 1  South Michelleport  2019-03-04 18:24:09  30.24  2343912425577
# 2  Port Samanthamouth  2019-02-24 04:29:00  33.44  2005065760003
# 3          Rodneyfort  2019-02-10 23:22:03  23.44  5149245426178
# 4          South Jack  2019-03-06 04:28:35  34.58  3908451377344
#
#    driver_count   type
# 0             5  Urban
# 1            72  Urban
# 2            57  Urban
# 3            34  Urban
# 4            46  Urban

# %%
#Create Suburban Data Frame
suburban_cities_df = ride_city_df[ride_city_df["type"]=="Suburban"]
suburban_cities_df.head()
# Out:
#                city                 date   fare        ride_id  driver_count  \
# 1625  Barronchester  2019-01-27 03:08:01  27.79  6653622887913            11
# 1626  East Kentstad  2019-04-07 19:44:19  18.75  6575961095852            20
# 1627      Lake Omar  2019-01-17 21:33:35  21.71   966911700371            22
# 1628     Myersshire  2019-02-27 17:38:39  17.10  5706770909868            19
# 1629    West Hannah  2019-04-19 01:06:59  37.78  2273047151891            12
#
#           type
# 1625  Suburban
# 1626  Suburban
# 1627  Suburban
# 1628  Suburban
# 1629  Suburban

# %%
rural_cities_df = ride_city_df[ride_city_df["type"]=="Rural"]
rural_cities_df
# Out:
#                  city                 date   fare        ride_id  \
# 2250   Randallchester  2019-04-13 11:13:31  43.22  1076079536213
# 2251      North Holly  2019-02-02 14:54:00  12.42  1985256326182
# 2252      Michaelberg  2019-03-27 18:27:34  54.85  4421836952718
# 2253  Lake Latoyabury  2019-02-23 21:12:24  47.90  3269652929887
# 2254  Lake Latoyabury  2019-05-06 08:57:56  51.80  4018025271936
# ...               ...                  ...    ...            ...
# 2370      Michaelberg  2019-04-29 17:04:39  13.38  8550365057598
# 2371  Lake Latoyabury  2019-01-30 00:05:47  20.76  9018727594352
# 2372      North Jaime  2019-02-10 21:03:50  11.11  2781339863778
# 2373     West Heather  2019-05-07 19:22:15  44.94  4256853490277
# 2374       Newtonview  2019-04-25 10:20:13  55.84  9990581345298
#
#       driver_count   type
# 2250             9  Rural
# 2251             8  Rural
# 2252             6  Rural
# 2253             2  Rural
# 2254             2  Rural
# ...

# %%
#Number of rides for urban cities
urban_ride_count = urban_cities_df.groupby(["city"]).count()["ride_id"]
urban_ride_count.head()
# Out:
# city
# Amandaburgh        18
# Barajasview        22
# Carriemouth        27
# Christopherfurt    27
# Deanville          19
# Name: ride_id, dtype: int64

# %%
#Number of rides for suburban cities
suburban_ride_count = suburban_cities_df.groupby(["city"]).count()["ride_id"]
suburban_ride_count.head()
# Out:
# city
# Barronchester    16
# Bethanyland      18
# Brandonfort      19
# Colemanland      22
# Davidfurt        17
# Name: ride_id, dtype: int64

# %%
#Number of rides for Rural cities
rural_ride_count = rural_cities_df.groupby(["city"]).count()["ride_id"]
rural_ride_count.head()
# Out:
# city
# Bradshawfurt      10
# Garzaport          3
# Harringtonfort     6
# Jessicaport        6
# Lake Jamie         6
# Name: ride_id, dtype: int64

# %%
#Avg fare for each city in urban cities
urban_avg_fare = urban_cities_df.groupby(["city"]).mean()["fare"]
urban_avg_fare.head()
# Out:
# city
# Amandaburgh        24.641667
# Barajasview        25.332273
# Carriemouth        28.314444
# Christopherfurt    24.501852
# Deanville          25.842632
# Name: fare, dtype: float64

# %%
#Avg fare for each city in suburbs
suburban_avg_fare = suburban_cities_df.groupby(["city"]).mean()["fare"]
suburban_avg_fare.head()
# Out:
# city
# Barronchester    36.422500
# Bethanyland      32.956111
# Brandonfort      35.437368
# Colemanland      30.894545
# Davidfurt        31.995882
# Name: fare, dtype: float64

# %%
#Avg fare for each Rural City
rural_avg_fare = rural_cities_df.groupby(["city"]).mean()["fare"]
rural_avg_fare.head()
# Out:
# city
# Bradshawfurt      40.064000
# Garzaport         24.123333
# Harringtonfort    33.470000
# Jessicaport       36.013333
# Lake Jamie        34.358333
# Name: fare, dtype: float64

# %%
#Avg Number of Drivers for Each Urban City
urban_driver_count = urban_cities_df.groupby(["city"]).mean()["driver_count"]
urban_driver_count.head()
# Out:
# city
# Amandaburgh        12.0
# Barajasview        26.0
# Carriemouth        52.0
# Christopherfurt    41.0
# Deanville          49.0
# Name: driver_count, dtype: float64

# %%
#Avg Number of Drivers for Each city in Suburbs
suburban_driver_count = suburban_cities_df.groupby(["city"]).mean()["driver_count"]
suburban_driver_count.head()
# Out:
# city
# Barronchester    11.0
# Bethanyland      22.0
# Brandonfort      10.0
# Colemanland      23.0
# Davidfurt        23.0
# Name: driver_count, dtype: float64

# %%
rural_driver_count = rural_cities_df.groupby(["city"]).mean()["driver_count"]
rural_driver_count.head()
# Out:
# city
# Bradshawfurt      7.0
# Garzaport         7.0
# Harringtonfort    4.0
# Jessicaport       1.0
# Lake Jamie        4.0
# Name: driver_count, dtype: float64

# %%
#Build the scatter plots for urban cities
plt.scatter(urban_ride_count,urban_avg_fare, s=10*urban_driver_count,
           color="coral",edgecolor="black", linewidths=1,
           alpha=0.8,label="Urban")
plt.title("PyBer Ride-Sharing Data (2019)")
plt.ylabel("Avg Fare ($)")
plt.xlabel("Total Number of Rides (Per City)")
plt.grid(True)
plt.legend()

# %%
#Scatter plot for Suburbs
plt.scatter(suburban_ride_count,suburban_avg_fare,color="skyblue",
            s=10*suburban_driver_count,edgecolor="black",linewidths=1,
           alpha=0.8,label="Suburban")
plt.title("PyBer Ride-Sharing Data (2019)")
plt.ylabel("Average Fare ($)")
plt.xlabel("Total Number of Rides (Per City)")
plt.grid(True)
plt.legend()

# %%
#Scatter plot for Rural Cities
plt.scatter(rural_ride_count,rural_avg_fare,color="gold",
           edgecolor="black",linewidths=1,alpha=0.8,label="Rural",
           s=10*rural_driver_count)
plt.title("PyBer Ride-Sharing Data (2019)")
plt.ylabel("Avg Fare ($)")
plt.xlabel("Total Number of Rides (Per City)")
plt.grid(True)
plt.legend()

# %%
# Build the scatter charts for each city type.
plt.subplots(figsize=(10, 6))
plt.scatter(urban_ride_count,
      urban_avg_fare,
      s=10*urban_driver_count, c="coral",
      edgecolor="black", linewidths=1,
      alpha=0.8, label="Urban")

plt.scatter(suburban_ride_count,
      suburban_avg_fare,
      s=10*suburban_driver_count, c="skyblue",
      edgecolor="black", linewidths=1,
      alpha=0.8, label="Suburban")

plt.scatter(rural_ride_count,
      rural_avg_fare,
      s=10*rural_driver_count, c="gold",
      edgecolor="black", linewidths=1,
      alpha=0.8, label="Rural")

# Incorporate the other graph properties
plt.title("PyBer Ride-Sharing Data (2019)", fontsize=20)
plt.ylabel("Average Fare ($)", fontsize=12)
plt.xlabel("Total Number of Rides (Per City)", fontsize=12)
plt.grid(True)

#Create a legend
lgnd = plt.legend(fontsize="12", mode="Expanded",
         scatterpoints=1, loc="best", title="City Types")
lgnd.legendHandles[0]._sizes = [75]
lgnd.legendHandles[1]._sizes = [75]
lgnd.legendHandles[2]._sizes = [75]
lgnd.get_title().set_fontsize(12)

# Add the legend.
plt.legend()

#Incorporate a text label about the circle size.
plt.text(42,35,"Note: Circle size correlates with driver count per city.",
        fontsize="12")

#Save the figure to Analysis folder
plt.savefig("Analysis/Fig1.png")


# Show the plot
plt.show()

# %%
#Summary Stats

# %%
#Describe Urban df
urban_cities_df.describe()
# Out:
#               fare       ride_id  driver_count
# count  1625.000000  1.625000e+03   1625.000000
# mean     24.525772  4.873485e+12     36.678154
# std      11.738649  2.907440e+12     20.075545
# min       4.050000  1.458810e+10      3.000000
# 25%      14.550000  2.400244e+12     22.000000
# 50%      24.640000  4.711188e+12     37.000000
# 75%      34.580000  7.451579e+12     52.000000
# max      44.970000  9.991538e+12     73.000000

# %%
#describe suburbs Df
suburban_cities_df.describe()
# Out:
#              fare       ride_id  driver_count
# count  625.000000  6.250000e+02    625.000000
# mean    30.970128  4.971015e+12     13.712000
# std     10.677508  2.912410e+12      8.042372
# min     12.050000  3.218337e+08      1.000000
# 25%     21.970000  2.364253e+12      5.000000
# 50%     30.750000  5.053221e+12     16.000000
# 75%     39.830000  7.551674e+12     21.000000
# max     49.960000  9.917744e+12     25.000000

# %%
#Describe rural Df
rural_cities_df.describe()
# Out:
#              fare       ride_id  driver_count
# count  125.000000  1.250000e+02    125.000000
# mean    34.623440  4.647746e+12      4.296000
# std     14.558046  2.887834e+12      2.691156
# min     10.110000  2.684873e+10      1.000000
# 25%     19.900000  2.275364e+12      1.000000
# 50%     37.050000  4.023962e+12      4.000000
# 75%     47.070000  7.118047e+12      7.000000
# max     58.550000  9.990581e+12      9.000000

# %%
#Urban ride count
urban_ride_count.describe()
# Out:
# count    66.000000
# mean     24.621212
# std       5.408726
# min      12.000000
# 25%      21.000000
# 50%      24.000000
# 75%      28.000000
# max      39.000000
# Name: ride_id, dtype: float64

# %%
#Suburban rides count
suburban_ride_count.describe()
# Out:
# count    36.000000
# mean     17.361111
# std       4.323707
# min       9.000000
# 25%      14.000000
# 50%      17.000000
# 75%      19.250000
# max      27.000000
# Name: ride_id, dtype: float64

# %%
#Rural Rides Count
rural_ride_count.describe()
# Out:
# count    18.000000
# mean      6.944444
# std       2.508157
# min       3.000000
# 25%       5.250000
# 50%       6.000000
# 75%       8.750000
# max      12.000000
# Name: ride_id, dtype: float64

# %%
# Calculate the mean of the ride count for each city type
round(urban_ride_count.mean(),2), round(suburban_ride_count.mean(),2), round(rural_ride_count.mean(),2)
# Out:
# (24.62, 17.36, 6.94)

# %%
#Calculate the median of the ride count for each city type
round(urban_ride_count.median(),2),round(suburban_ride_count.median(),2),round(rural_ride_count.median(),2)
# Out:
# (24.0, 17.0, 6.0)

# %%
#Calculate the mode of the ride count for each city type
urban_ride_count.mode(),suburban_ride_count.mode(),rural_ride_count.mode()
# Out:
# (0    22
#  1    25
#  dtype: int64,
#  0    17
#  dtype: int64,
#  0    6
#  dtype: int64)

# %%
#Using Numpy and Scipy to calc Summary Stats
import numpy as np
import scipy.stats as sts

# %%
#Calc Measures of Central Tendency (mean,median,mode) for ride count in urban cities
mean_urban_ride_count = np.mean(urban_ride_count)
print(f"The mean for the ride counts for urban trips is {mean_urban_ride_count:.2f}.")

median_urban_ride_count = np.median(urban_ride_count)
print(f"The median for ride counts for urban trips is {median_urban_ride_count}.")

mode_urban_ride_count = sts.mode(urban_ride_count)
print(f"The mode for ride counts for urban trips is {mode_urban_ride_count}.")
# Out:
# The mean for the ride counts for urban trips is 24.62.
# The median for ride counts for urban trips is 24.0.
# The mode for ride counts for urban trips is ModeResult(mode=array([22], dtype=int64), count=array([7])).

# %%
mode_suburban_ride_count = sts.mode(suburban_ride_count)
mode_suburban_ride_count
# Out:
# ModeResult(mode=array([17], dtype=int64), count=array([7]))

# %%
mode_rural_ride_count = sts.mode(rural_ride_count)
mode_rural_ride_count
# Out:
# ModeResult(mode=array([6], dtype=int64), count=array([5]))

# %%
#Fares for urban cities
urban_fares = urban_cities_df["fare"]
urban_fares.head()
# Out:
# 0    13.83
# 1    30.24
# 2    33.44
# 3    23.44
# 4    34.58
# Name: fare, dtype: float64

# %%
#Measures of Central Tendency for Avg Fare for Urban Cities
mean_urban_fares = np.mean(urban_fares)
print(mean_urban_fares)
median_urban_fares = np.median(urban_fares)
print(median_urban_fares)
mode_urban_fares = sts.mode(urban_fares)
print(mode_urban_fares)
# Out:
# 24.52577230769236
# 24.64
# ModeResult(mode=array([22.86]), count=array([5]))

# %%
#Avg fare price for suburbs
suburban_fares = suburban_cities_df["fare"]
mean_suburban_fares = np.mean(suburban_fares)
print(mean_suburban_fares)
#Avg fare price for rural areas
rural_fares = rural_cities_df["fare"]
mean_rural_fares = np.mean(rural_fares)
print(mean_rural_fares)
# Out:
# 30.97012800000002
# 34.623440000000016

# %%
#Driver count data from urban areas
urban_drivers = urban_cities_df["driver_count"]
urban_drivers.head()
# Out:
# 0     5
# 1    72
# 2    57
# 3    34
# 4    46
# Name: driver_count, dtype: int64

# %%
#Avg number of drivers in Urban Areas
mean_urban_drivers = np.mean(urban_drivers)
print(mean_urban_drivers)

#Avg number of drivers in Suburbs
suburban_drivers = suburban_cities_df["driver_count"]
mean_suburban_drivers = np.mean(suburban_drivers)
print(mean_suburban_drivers)

#Avg number of drivers in Rural Areas
rural_drivers = rural_cities_df["driver_count"]
mean_rural_drivers = np.mean(rural_drivers)
print(mean_rural_drivers)
# Out:
# 36.67815384615385
# 13.712
# 4.296

# %%
#Urban Ride Count Box-&-Whisker
x_labels = ["Urban"]
fig,ax = plt.subplots()
ax.boxplot(urban_ride_count,labels=x_labels)
#Add the title, y-axis label and grid
ax.set_title("Ride Count Data (2019)")
ax.set_ylabel("Number of Rides")
ax.set_yticks(np.arange(np.min(urban_ride_count)-2,np.max(urban_ride_count)+2,step=2.0))
ax.grid()
plt.show()

# %%
#Add all ride count box-&-whisker plots to same graph
x_labels = ["Urban","Suburban","Rural"]
ride_count_data = [urban_ride_count,suburban_ride_count,rural_ride_count]
fig,ax = plt.subplots(figsize=(10,6))
ax.set_title("Ride Count Data(2019)",fontsize=20)
ax.set_ylabel("Number of Rides",fontsize=14)
ax.set_xlabel("City Types",fontsize=14)
ax.boxplot(ride_count_data,labels = x_labels)
ax.set_yticks(np.arange(0,45,step=3.0))
ax.grid()
#Save figure/graph
plt.savefig("Analysis/Fig2.png")
plt.show()

# %%
#Get the city that matches 39
urban_city_outlier = urban_ride_count[urban_ride_count==39].index[0]
print(f"{urban_city_outlier} has the highest rider count.")
# Out:
# West Angela has the highest rider count.

# %%
#Create a box-and-whisker plot for the urban fare data
x_labels = ["Urban"]
fig,ax = plt.subplots()
ax.boxplot(urban_fares,labels=x_labels)
# Add the title, y-axis label, and grid
ax.set_title("Ride Fare Data (2019)")
ax.set_ylabel("Fare($USD)")
ax.set_yticks(np.arange(0,51,step=5.0))
ax.grid()
plt.show()
print("Summary Statistics")
urban_fares.describe()
# Out:
# Summary Statistics
# count    1625.000000
# mean       24.525772
# std        11.738649
# min         4.050000
# 25%        14.550000
# 50%        24.640000
# 75%        34.580000
# max        44.970000
# Name: fare, dtype: float64

# %%
#Create Box-&-Whisker plot for ride fares in all three city-types in one graph
x_labels = ["Urban","Suburban","Rural"]
ride_fare_data = [urban_fares,suburban_fares,rural_fares]
fig,ax = plt.subplots(figsize=(10,6))
ax.set_title("Ride Fare Data(2019)",fontsize=20)
ax.set_ylabel("Fare ($)",fontsize=14)
ax.set_xlabel("City Types",fontsize=14)
ax.boxplot(ride_fare_data,labels = x_labels)
ax.set_yticks(np.arange(0,75,step=5.0))
ax.grid()
plt.savefig("Analysis/BoxWhiskerRideFare.png")
plt.show()

# %%
#Create box-&-whisker plot for urban driver count data
x_labels = ["Urban"]
fig,ax = plt.subplots()
ax.boxplot(urban_drivers,labels=x_labels)
ax.set_title("Driver Count Data (2019)")
ax.set_ylabel("Number of Driver")
ax.set_yticks(np.arange(0,90,step=5.0))
ax.grid()
plt.show()
print("Summary Stats")
urban_drivers.describe()
# Out:
# Summary Stats
# count    1625.000000
# mean       36.678154
# std        20.075545
# min         3.000000
# 25%        22.000000
# 50%        37.000000
# 75%        52.000000
# max        73.000000
# Name: driver_count, dtype: float64

# %%
# Box-&-Whisker All 3 City types' driver count
x_labels = ["Urban","Suburban","Rural"]
driver_count_data = [urban_drivers,suburban_drivers,rural_drivers]
fig,ax = plt.subplots(figsize=(10,6))
ax.set_title("Driver Count Data(2019)",fontsize=20)
ax.set_ylabel("Number of Drivers",fontsize=14)
ax.set_xlabel("City Types",fontsize=14)
ax.boxplot(driver_count_data,labels = x_labels)
ax.set_yticks(np.arange(0,75,step=5.0))
ax.grid()
plt.savefig("Analysis/BoxWhiskerDriverCount.png")
plt.show()
